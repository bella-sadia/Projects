# %%
import os
import torch
from fastai import *
from fastai.basics import *
from fastai.callback.all import *
from fastai.vision import *
from fastai.vision.all import *
from fastai.metrics import error_rate, accuracy
import timm
import numpy as np
import pandas as pd
import matplotlib as plt
import random
from PIL import Image

# %%
path = Path('./test_images')
path.ls()

# [Path('train_images/bacterial_leaf_streak'),Path('train_images/blast'),Path('train_images/hispa'),Path('train_images/tungro'),Path('train_images/downy_mildew'),Path('train_images/bacterial_leaf_blight'),Path('train_images/bacterial_panicle_blight'),Path('train_images/dead_heart'),Path('train_images/brown_spot'),Path('train_images/normal')]
# Out:
# (#3469) [Path('test_images/200196.jpg'),Path('test_images/201289.jpg'),Path('test_images/202415.jpg'),Path('test_images/202338.jpg'),Path('test_images/201205.jpg'),Path('test_images/201606.jpg'),Path('test_images/200906.jpg'),Path('test_images/200006.jpg'),Path('test_images/200076.jpg'),Path('test_images/202537.jpg')...]

# %%
trn_path = path
files = get_image_files(trn_path)

# %%
img = PILImage.create(files[0])
print(img.size)
img.to_thumb(128)
# Out:
# (480, 640)
# <PIL.Image.Image image mode=RGB size=96x128>

# %%
from fastcore.parallel import *

def f(o): return PILImage.create(o).size
sizes = parallel(f, files, n_workers=8)
pd.Series(sizes).value_counts()
# Out:
# (480, 640)    3469
# dtype: int64

# %% [markdown]
# # train_images
#
# ## bacterial_leaf_blight - (480, 640)    477 , (640, 480)      2
#
# ## brown_spot - (480, 640)    963 , (640, 480)      2
# 103050.jpg, 103343.jpg
#
# # test_images
#
# ## (480, 640)    3467 , (640, 480)       2
# 200533.jpg, 200916.jpg
